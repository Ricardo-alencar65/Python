# %%
nasc = int(input("Digite a sua data de nascimento: "));
ano_atual = int(input ("digite o ano atual: "));
while ano_atual < 2122:
    idade = int(ano_atual - nasc);
    print(f"sua idade em {ano_atual} vai ser {idade}");
    ano_atual += 1
# Out:
# Digite a sua data de nascimento: 2003
# digite o ano atual: 2022
# sua idade em 2022 vai ser 19
# sua idade em 2023 vai ser 20
# sua idade em 2024 vai ser 21
# sua idade em 2025 vai ser 22
# sua idade em 2026 vai ser 23
# sua idade em 2027 vai ser 24
# sua idade em 2028 vai ser 25
# sua idade em 2029 vai ser 26
# sua idade em 2030 vai ser 27
# sua idade em 2031 vai ser 28
# sua idade em 2032 vai ser 29
# sua idade em 2033 vai ser 30
# sua idade em 2034 vai ser 31
# sua idade em 2035 vai ser 32
# sua idade em 2036 vai ser 33
# sua idade em 2037 vai ser 34
# sua idade em 2038 vai ser 35
# sua idade em 2039 vai ser 36
# sua idade em 2040 vai ser 37
# sua idade em 2041 vai ser 38
# sua idade em 2042 vai ser 39
# sua idade em 2043 vai ser 40
# sua idade em 2044 vai ser 41
# sua idade em 2045 vai ser 42
# sua idade em 2046 vai ser 43
# sua idade em 2047 vai ser 44
# sua idade em 2048 vai ser 45
# sua idade em 2049 vai ser 46
# sua idade em 2050 vai ser 47
# sua idade em 2051 vai ser 48
# ...
